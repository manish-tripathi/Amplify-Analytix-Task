# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Initialize variables
base_url = "https://live.euronext.com/en/ipo-showcase/all?field_iponi_ipo_date_value%5Bmin%5D=&field_iponi_ipo_date_value%5Bmax%5D=&page="
page_number = 0
ipo_dates = []
companies = []
links = []

while True:
    # Construct the URL for the current page
    url = f"{base_url}{page_number}"
    
    # Send an HTTP request to the URL
    response = requests.get(url)
    
    # Ensure the request was successful
    if response.status_code != 200:
        print(f'Failed to retrieve page {page_number} with status code: {response.status_code}')
        break  # Exit the loop if the request fails
    
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Check if the page contains any IPO listings
    ipo_listing_tags = soup.find_all('td', {'class': 'views-field views-field-field-iponi-ipo-date'})
    if not ipo_listing_tags:
        break  # Exit the loop if there are no more IPO listings
    
    # Extract data from the current page
    for td_date, td_company in zip(soup.find_all('td', {'class': 'views-field views-field-field-iponi-ipo-date'}),
                                   soup.find_all('td', {'class': 'views-field views-field-field-iponi-display-title'})):
        # Extract IPO date
        ipo_date_tag = td_date.find('time')
        if ipo_date_tag:
            ipo_dates.append(ipo_date_tag.text)
        else:
            ipo_dates.append(None)
        
        # Extract company name and link
        company_tag = td_company.find('a')
        if company_tag:
            companies.append(company_tag.text)
            links.append(company_tag['href'])
        else:
            companies.append(None)
            links.append(None)
    
    # Increment the page number for the next iteration
    page_number += 1

# Create a DataFrame to store the extracted data
df = pd.DataFrame({
    'IPO Date': ipo_dates,
    'Company': companies,
    'Link': links
})

# Print the DataFrame
print(df)
# Out:
#         IPO Date                         Company  \
# 0     05/10/2023                      BEERENBERG
# 1     03/10/2023                             QEV
# 2     02/10/2023                          AQUILA
# 3     29/09/2023                     EMMA VILLAS
# 4     29/09/2023                          VALICA
# ...          ...                             ...
# 2734  05/11/2003                  GRUPPO FORMULA
# 2735  14/07/2003                       GESCARTAO
# 2736  10/07/2003                          KARDAN
# 2737  10/07/2003                          KARDAN
# 2738  09/04/2003  Banco Comercial dos Açores, SA
#
#                                                  Link
# 0                         /en/ipo-showcase/beerenberg
# 1             /en/ipo-showcase/spear-investments-1-bv
# 2     /en/ipo-showcase/aquila-european-renewables-plc
# 3                        /en/ipo-showcase/emma-villas
# 4                             /en/ipo-showcase/valica
# ...                                               ...
# 2734                  /fr/ipo-showcase/gruppo-formula
# 2735                       /en/ipo-showcase/gescartao
# 2736                          /en/ipo-showcase/kardan
# 2737                          /nl/ipo-showcase/kardan
# 2738   /pt/ipo-showcase/banco-comercial-dos-acores-sa
#
# [2739 rows x 3 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Send an HTTP request to the URL
url = 'https://live.euronext.com/en/ipo-showcase/all'
response = requests.get(url)

# Ensure the request was successful
if response.status_code != 200:
    print(f'Failed to retrieve page with status code: {response.status_code}')

# Parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Initialize empty lists to store the extracted data
ipo_dates = []
companies = []
links = []

# Find all the td elements with the specified class for IPO date
for td_date, td_company in zip(soup.find_all('td', {'class': 'views-field views-field-field-iponi-ipo-date'}),
                               soup.find_all('td', {'class': 'views-field views-field-field-iponi-display-title'})):
    # Extract IPO date
    ipo_date_tag = td_date.find('time')
    if ipo_date_tag:
        ipo_dates.append(ipo_date_tag.text)
    else:
        ipo_dates.append(None)
    
    # Extract company name and link
    company_tag = td_company.find('a')
    if company_tag:
        companies.append(company_tag.text)
        links.append(company_tag['href'])
    else:
        companies.append(None)
        links.append(None)

# Create a DataFrame to store the extracted data
df = pd.DataFrame({
    'IPO Date': ipo_dates,
    'Company': companies,
    'Link': links
})

# Print the DataFrame
print(df)
# Out:
#       IPO Date               Company  \
# 0   05/10/2023            BEERENBERG
# 1   03/10/2023                   QEV
# 2   02/10/2023                AQUILA
# 3   29/09/2023           EMMA VILLAS
# 4   29/09/2023                VALICA
# 5   29/09/2023      MATVAREEXPRESSEN
# 6   28/09/2023             COTY INC.
# 7   28/09/2023                PRECIA
# 8   28/09/2023        ELSA SOLUTIONS
# 9   27/09/2023           NORTEM CHEM
# 10  27/09/2023       EDIL SAN FELICE
# 11  19/09/2023         ARVERNE GROUP
# 12  01/09/2023           DMS IMAGING
# 13  09/08/2023                LA SIA
# 14  09/08/2023               E-GLOBE
# 15  04/08/2023           ARRAS GROUP
# 16  04/08/2023                EXECUS
# 17  04/08/2023  PORTO AVIATION GROUP
# 18  03/08/2023          iVision Tech
# 19  03/08/2023        Sicily by Car
#
#                                                Link
# 0                       /en/ipo-showcase/beerenberg
# 1           /en/ipo-showcase/spear-investments-1-bv
# 2   /en/ipo-showcase/aquila-european-renewables-plc
# 3                      /en/ipo-showcase/emma-villas
# 4                           /en/ipo-showcase/valica
# 5                 /en/ipo-showcase/matvareexpressen
# 6                         /en/ipo-showcase/coty-inc
# 7                           /en/ipo-showcase/precia
# 8                   /en/ipo-showcase/elsa-solutions
# 9                   /en/ipo-showcase/nortem-chem-sa
# 10                 /en/ipo-showcase/edil-san-felice
# 11                /en/ipo-showcase/arverne-group-sa
# 12                  /en/ipo-showcase/dms-imaging-sa
# 13                          /en/ipo-showcase/la-sia
# 14                         /en/ipo-showcase/e-globe
# 15                     /en/ipo-showcase/arras-group
# 16                          /en/ipo-showcase/execus
# 17            /en/ipo-showcase/porto-aviation-group
# 18                    /en/ipo-showcase/ivision-tech
# 19                      /en/ipo-showcase/sicily-car

# %%
df['Link'] = 'https://live.euronext.com' + df['Link']

# %%
df
# Out:
#       IPO Date               Company  \
# 0   05/10/2023            BEERENBERG
# 1   03/10/2023                   QEV
# 2   02/10/2023                AQUILA
# 3   29/09/2023           EMMA VILLAS
# 4   29/09/2023                VALICA
# 5   29/09/2023      MATVAREEXPRESSEN
# 6   28/09/2023             COTY INC.
# 7   28/09/2023                PRECIA
# 8   28/09/2023        ELSA SOLUTIONS
# 9   27/09/2023           NORTEM CHEM
# 10  27/09/2023       EDIL SAN FELICE
# 11  19/09/2023         ARVERNE GROUP
# 12  01/09/2023           DMS IMAGING
# 13  09/08/2023                LA SIA
# 14  09/08/2023               E-GLOBE
# 15  04/08/2023           ARRAS GROUP
# 16  04/08/2023                EXECUS
# 17  04/08/2023  PORTO AVIATION GROUP
# 18  03/08/2023          iVision Tech
# 19  03/08/2023        Sicily by Car
#
#                                                  Link
# 0   https://live.euronext.com/en/ipo-showcase/beer...
# 1   https://live.euronext.com/en/ipo-showcase/spea...
# 2   https://live.euronext.com/en/ipo-showcase/aqui...
# 3   https://live.euronext.com/en/ipo-showcase/emma...
# 4    https://live.euronext.com/en/ipo-showcase/valica
# 5   https://live.euronext.com/en/ipo-showcase/matv...
# 6   https://live.euronext.com/en/ipo-showcase/coty...
# 7    https://live.euronext.com/en/ipo-showcase/precia
# 8   https://live.euronext.com/en/ipo-showcase/elsa...
# 9   https://live.euronext.com/en/ipo-showcase/nort...
# 10  https://live.euronext.com/en/ipo-showcase/edil...
# 11  https://live.euronext.com/en/ipo-showcase/arve...
# 12  https://live.euronext.com/en/ipo-showcase/dms-...
# 13   https://live.euronext.com/en/ipo-showcase/la-sia
# 14  https://live.euronext.com/en/ipo-showcase/e-globe
# 15  https://live.euronext.com/en/ipo-showcase/arra...
# 16   https://live.euronext.com/en/ipo-showcase/execus
# 17  https://live.euronext.com/en/ipo-showcase/port...
# 18  https://live.euronext.com/en/ipo-showcase/ivis...
# 19  https://live.euronext.com/en/ipo-showcase/sici...

# %%
# Initialize an empty list to store the ICB values
icb_values = []

# Iterate over each link in the df['Link'] column
for link in df['Link']:
    # Send an HTTP request to the link
    response = requests.get(link)
    
    # Ensure the request was successful
    if response.status_code != 200:
        print(f'Failed to retrieve page {link} with status code: {response.status_code}')
        icb_values.append(None)  # Append None for failed requests
        continue  # Skip to the next iteration
    
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the ICB field div
    icb_div = soup.find('div', {'class': 'field--name-field-icb'})
    
    # Extract the ICB value
    if icb_div:
        icb_value = icb_div.find('div', {'class': 'field__item'})
        icb_values.append(icb_value.text.strip() if icb_value else None)
    else:
        icb_values.append(None)  # Append None if the ICB field is not found

# Add a new column to the DataFrame with the ICB values
df['ICB'] = icb_values

# (Optional) Print the updated DataFrame to check the results
print(df)
# Out:
#       IPO Date               Company  \
# 0   05/10/2023            BEERENBERG
# 1   03/10/2023                   QEV
# 2   02/10/2023                AQUILA
# 3   29/09/2023           EMMA VILLAS
# 4   29/09/2023                VALICA
# 5   29/09/2023      MATVAREEXPRESSEN
# 6   28/09/2023             COTY INC.
# 7   28/09/2023                PRECIA
# 8   28/09/2023        ELSA SOLUTIONS
# 9   27/09/2023           NORTEM CHEM
# 10  27/09/2023       EDIL SAN FELICE
# 11  19/09/2023         ARVERNE GROUP
# 12  01/09/2023           DMS IMAGING
# 13  09/08/2023                LA SIA
# 14  09/08/2023               E-GLOBE
# 15  04/08/2023           ARRAS GROUP
# 16  04/08/2023                EXECUS
# 17  04/08/2023  PORTO AVIATION GROUP
# 18  03/08/2023          iVision Tech
# 19  03/08/2023        Sicily by Car
#
#                                                  Link  \
# 0   https://live.euronext.com/en/ipo-showcase/beer...
# 1   https://live.euronext.com/en/ipo-showcase/spea...
# 2   https://live.euronext.com/en/ipo-showcase/aqui...
# 3   https://live.euronext.com/en/ipo-showcase/emma...
# 4    https://live.euronext.com/en/ipo-showcase/valica
# 5   https://live.euronext.com/en/ipo-showcase/matv...
# 6   https://live.euronext.com/en/ipo-showcase/coty...
# 7    https://live.euronext.com/en/ipo-showcase/precia
# 8   https://live.euronext.com/en/ipo-showcase/elsa...
# 9   https://live.euronext.com/en/ipo-showcase/nort...
# 10  https://live.euronext.com/en/ipo-showcase/edil...
# 11  https://live.euronext.com/en/ipo-showcase/arve...
# 12  https://live.euronext.com/en/ipo-showcase/dms-...
# 13   https://live.euronext.com/en/ipo-showcase/la-sia
# 14  https://live.euronext.com/en/ipo-showcase/e-globe
# 15  https://live.euronext.com/en/ipo-showcase/arra...
# 16   https://live.euronext.com/en/ipo-showcase/execus
# 17  https://live.euronext.com/en/ipo-showcase/port...
# 18  https://live.euronext.com/en/ipo-showcase/ivis...
# 19  https://live.euronext.com/en/ipo-showcase/sici...
#
#                                                   ICB
# 0                 60101030 Oil Equipment and Services
# 1                                                None
# 2                     30204000 Closed End Investments
# 3        35101010 Real Estate Holding and Development
# 4                  10101020 Consumer Digital Services
# 5             45201010 Food Retailers and Wholesalers
# 6                                  40204035 Cosmetics
# 7    50202025 Electronic Equipment: Gauges and Meters
# 8                      50202010 Electrical Components
# 9                     55201000 Chemicals: Diversified
# 10                              50101010 Construction
# 11                   65101010 Alternative Electricity
# 12                             20103010 Biotechnology
# 13      50101015 Engineering and Contracting Services
# 14                 50101025 Building: Climate Control
# 15       35101010 Real Estate Holding and Development
# 16  50205025 Business Training and Employment Agen...
# 17                                 50201010 Aerospace
# 18                          20102015 Medical Supplies
# 19     40201040 Rental and Leasing Services: Consumer
